# %% [markdown]
# # Qualia Investments

# %% [markdown]
# Data overview:<br>
# - Data was collected on 2019-09-17<br>
# - Dataset includes 124 upcoming events at Madison Square Garden<br>
# - See field tm_offers for current availability on Ticketmaster. Each element of tm_offers is a set of seats that are available at a specific price point. See tm_offers.offers.places for the seats and section.<br>
# - Field sh_listings.listing contains the current stubhub listings.<br>

# %%
# Importing Packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset

data=pd.read_json("madison_square_garden_tm_sh_data-2019-09-17.json")

# %% [markdown]
# # Exploratory Analysis
#
# ## Extracting data from TM for first event

# %%
l=data['tm_offers'][0]

# %%
import itertools
# First Event, where is a particular event
df = pd.DataFrame(columns=['event','faceValue','listPrice','totalPrice','noChargesPrice','section','row','seat','row_count'])
keys=['faceValue','listPrice','totalPrice','noChargesPrice']
keys2=['section','row','seat','row_count']
c=0
venue=['One']
for i in l:
    pricing=[i['offer'][key] for key in keys]
    for p in i['places']:
        seating=[p[key] for key in keys2]
        s=itertools.chain(venue,pricing,seating)
        df.loc[c]=list(s)
        c+=1

# %%
df
# Out:
#      event  faceValue  listPrice  totalPrice  noChargesPrice section row seat  \
# 0      One     119.00     119.00      141.00          113.00     101  11   17
# 1      One     119.00     119.00      141.00          113.00     101  11   18
# 2      One     119.00     119.00      141.00          113.00     101  12   18
# 3      One     119.00     119.00      141.00          113.00     101  12   19
# 4      One     119.00     119.00      141.00          113.00     101   8    5
# 5      One     119.00     119.00      141.00          113.00     101   8    6
# 6      One     119.00     119.00      141.00          113.00     101   8    7
# 7      One     119.00     119.00      141.00          113.00     101   8    8
# 8      One     119.00     119.00      141.00          113.00     101   8    9
# 9      One     119.00     119.00      141.00          113.00     101   8   10
# 10     One     119.00     119.00      141.00          113.00     101   8   11
# 11     One     119.00     119.00      141.00          113.00     101   8   12
# 12     One     119.00     119.00      141.00          113.00     101   9   13
# 13     One     119.00     119.00      141.00          113.00     101   9   14
# 14     One     119.00     119.00      141.00          113.00     101   9   15
# 15     One      79.00      79.00      100.00           73.00     101  17    3
# 16     One      79.00      79.00      100.00           73.00     101  17    4
# 17     One      79.00      79.00      100.00           73.00     101  17    7
# 18     One      79.00      79.00      100.00           73.00     101  17    8
# 19     One      79.00      79.00      100.00           73.00     101  13   10
# 20     One      79.00      79.00      100.00           73.00     101  13    7
# 21     One      79.00      79.00      100.00           73.00     101  13    8
# 22     One      79.00      79.00      100.00           73.00     101  13    9
# 23     One      79.00      79.00      100.00           73.00     101  14   13
# 24     One      79.00      79.00      100.00           73.00     101  14   14
# 25     One      79.00      79.00      100.00           73.00     101  14   15
# 26     One      79.00      79.00      100.00           73.00     101  14   16
# 27     One      79.00      79.00      100.00           73.00     101  16   13
# 28     One      79.00      79.00      100.00           73.00     101  16   14
# 29     One      79.00      79.00      100.00           73.00     101  16    5
# ...    ...        ...        ...         ...             ...     ...  ..  ...
# 2053   One     225.00     225.00      258.20          219.00       8   4    8
# 2054   One     225.00     225.00      258.20          219.00       8   5    7
# 2055   One     225.00     225.00      258.20          219.00       8   5    8
# 2056   One     648.25     648.25      705.55          514.25      8D  AA   13
# 2057   One     648.25     648.25      705.55          514.25      8D  AA   14
# 2058   One     648.25     648.25      705.55          514.25      8D  AA   15
# 2059   One     648.25     648.25      705.55          514.25      8D  AA   16
# 2060   One     225.00     225.00      258.20          219.00       9   1   11
# 2061   One     225.00     225.00      258.20          219.00       9   2    5
# 2062   One     225.00     225.00      258.20          219.00       9   3    5
# 2063   One     225.00     225.00      258.20          219.00       9   3    6
# 2064   One     225.00     225.00      258.20          219.00       9   3    7
# 2065   One     225.00     225.00      258.20          219.00       9   4    3
# 2066   One     225.00     225.00      258.20          219.00       9   4    4
# 2067   One     648.25     648.25      705.55          514.25      9D  AA   11
# 2068   One     648.25     648.25      705.55          514.25      9D  AA   12
# 2069   One     648.25     648.25      705.55          514.25      9D  AA   13
# 2070   One     648.25     648.25      705.55          514.25      9D  AA   14
# 2071   One     746.50     746.50      807.60          277.50    VIP1  AA    5
# 2072   One     746.50     746.50      807.60          277.50    VIP1  AA    6
# 2073   One     746.50     746.50      807.60          277.50    VIP2  AA   19
# 2074   One     746.50     746.50      807.60          277.50    VIP2  AA   20
# 2075   One     746.50     746.50      807.60          277.50    VIP4  AA    1
# 2076   One     746.50     746.50      807.60          277.50    VIP4  AA    2
# 2077   One     746.50     746.50      807.60          277.50    VIP4  AA    3
# 2078   One     746.50     746.50      807.60          277.50    VIP5  AA    3
# 2079   One     746.50     746.50      807.60          277.50    VIP5  AA    4
# 2080   One     746.50     746.50      807.60          277.50  VP12WC  AA    7
# 2081   One     746.50     746.50      807.60          277.50  VP12WC  AA    5
# 2082   One     746.50     746.50      807.60          277.50  VP12WC  AA    6
#
#      row_count
# 0           18
# 1           18
# 2           19
# 3           19
# 4           16
# 5           16
# 6           16
# 7           16
# 8           16
# 9           16
# 10          16
# 11          16
# 12          17
# 13          17
# 14          17
# 15          18
# 16          18
# 17          18
# 18          18
# 19          20
# 20          20
# 21          20
# 22          20
# 23          20
# 24          20
# 25          20
# 26          20
# 27          22
# 28          22
# 29          22
# ...        ...
# 2053        16
# 2054        14
# 2055        14
# 2056        18
# 2057        18
# 2058        18
# 2059        18
# 2060        11
# 2061         9
# 2062         7
# 2063         7
# 2064         7
# 2065         4
# 2066         4
# 2067        14
# 2068        14
# 2069        14
# 2070        14
# 2071        19
# 2072        19
# 2073         4
# 2074         4
# 2075         7
# 2076         7
# 2077         7
# 2078         4
# 2079         4
# 2080         7
# 2081         7
# 2082         7
#
# [2083 rows x 9 columns]
